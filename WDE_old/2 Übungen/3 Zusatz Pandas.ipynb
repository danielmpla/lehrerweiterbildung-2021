# %% [markdown]
# # Zusatzaufgabe 1 - Pandas in action
#
# ## Aufgabe:
#
# In dieser Aufgabe sollen nun von einer real existierenden Webseite die aktuellen Coronazahlen für den Landkreis Görlitz extrahiert werden.
#
# Hierfür nutzen sie bitte die folgende Webseite:
#
# http://coronavirus.landkreis.gr/
#
# Extrahieren sie hierfür unter Nutzung von Pandas und den Entwicklertools des Firefox-Browsers die detaillierten Coronazahlen von der Seite, die sich hinter dem Link "zur Übersicht der aktuellen Zahlen in den Kommunen (Gemeindetabelle)" (unterhalb der 1. oberen Tabelle) befinden.

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Lösung:

# %%
import pandas
import requests
#import lxml

#Ihre Lösung hier:
# Schritt 1: Laden der Seite
# Schritt 2: HTML mit Pandas laden
# Schritt 3: Tabelle ausgeben

# %% [markdown]
# ## Analyse der Ergebnisse:
#
# Sind die Ergebnisse wie gewünscht? Was fällt Ihnen in den Daten auf? Welche Unterschiede gibt es zu den originalen Daten und welche Schritte sind ggf. notwendig, um mit den Daten weiterarbeiten zu können?
# Haben Sie bereits Ideen, was Sie auf Grundlage dieser Daten zusätzliches berechnen könnten?
